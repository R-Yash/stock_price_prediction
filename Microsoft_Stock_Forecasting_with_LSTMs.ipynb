# %%
# dataset @ https://finance.yahoo.com/quote/MSFT/history/

# If you want the exact same dataset as the YouTube video,
# use this link: https://drive.google.com/file/d/1WLm1AEYgU28Nk4lY4zNkGPSctdImbhJI/view?usp=sharing

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060524  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062686   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063767   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.062145    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.061065    47894400

# %%
df = df[['Date', 'Close']]

df.head()
# Out:
#          Date     Close
# 0  1986-03-13  0.097222
# 1  1986-03-14  0.100694
# 2  1986-03-17  0.102431
# 3  1986-03-18  0.099826
# 4  1986-03-19  0.098090

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9422    2023-08-02
# 9423    2023-08-03
# 9424    2023-08-04
# 9425    2023-08-07
# 9426    2023-08-08
# Name: Date, Length: 9427, dtype: object

# %%
import datetime

# Converting the string column Date into a datetime column
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df.head()
# Out:
#          Date     Close
# 0  1986-03-13  0.097222
# 1  1986-03-14  0.100694
# 2  1986-03-17  0.102431
# 3  1986-03-18  0.099826
# 4  1986-03-19  0.098090

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9422   2023-08-02
# 9423   2023-08-03
# 9424   2023-08-04
# 9425   2023-08-07
# 9426   2023-08-08
# Name: Date, Length: 9427, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df.head()
# Out:
#                Close
# Date
# 1986-03-13  0.097222
# 1986-03-14  0.100694
# 1986-03-17  0.102431
# 1986-03-18  0.099826
# 1986-03-19  0.098090

# %%
import matplotlib.pyplot as plt

# Lets Plot the data
plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 102ms/step - loss: 84798.8828 - mean_absolute_error: 289.4644 - val_loss: 92413.0391 - val_mean_absolute_error: 303.9080
# Epoch 2/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84468.4844 - mean_absolute_error: 288.8916 - val_loss: 92142.5703 - val_mean_absolute_error: 303.4626
# Epoch 3/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84197.7109 - mean_absolute_error: 288.4233 - val_loss: 91841.2422 - val_mean_absolute_error: 302.9657
# Epoch 4/100
# 7/7 [==============================] - 0s 11ms/step - loss: 83899.9688 - mean_absolute_error: 287.9014 - val_loss: 91464.9531 - val_mean_absolute_error: 302.3441
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 83502.5156 - mean_absolute_error: 287.2150 - val_loss: 90991.3203 - val_mean_absolute_error: 301.5598
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 83000.2891 - mean_absolute_error: 286.3382 - val_loss: 90343.0625 - val_mean_absolute_error: 300.4831
# Epoch 7/100
# 7/7 [==============================] - 0s 8ms/step - loss: 82318.8047 - mean_absolute_error: 285.1472 - val_loss: 89544.7031 - val_mean_absolute_error: 299.1517
# Epoch 8/100
# 7/7 [==============================] - 0s 9ms/step - loss: 81484.6797 - mean_absolute_error: 283.6792 - val_loss: 88471.8438 - val_mean_absolute_error: 297.3531
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 80314.2656 - mean_absolute_error: 281.6106 - val_loss: 87032.8203 - val_mean_absolute_error: 294.9234
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 78870.6641 - mean_absolute_error: 279.0311 - val_loss: 85322.3281 - val_mean_absolute_error: 292.0092
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 77139.8828 - mean_absolute_error: 275.9055 - val_loss: 83312.1562 - val_mean_absolute_error: 288.5465
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 75018.1719 - mean_absolute_error: 272.0346 - val_loss: 80786.3984 - val_mean_absolute_error: 284.1363
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 72542.5703 - mean_absolute_error: 267.4608 - val_loss: 77926.4922 - val_mean_absolute_error: 279.0582
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - loss: 69629.2656 - mean_absolute_error: 261.9515 - val_loss: 74552.5312 - val_mean_absolute_error: 272.9460
# Epoch 15/100
# 7/7 [==============================] - 0s 8ms/step - loss: 66314.8594 - mean_absolute_error: 255.5254 - val_loss: 70820.8281 - val_mean_absolute_error: 266.0223
# Epoch 16/100
# 7/7 [==============================] - 0s 9ms/step - loss: 62693.2852 - mean_absolute_error: 248.3592 - val_loss: 66811.6016 - val_mean_absolute_error: 258.3769
# Epoch 17/100
# 7/7 [==============================] - 0s 8ms/step - loss: 58766.8047 - mean_absolute_error: 240.3471 - val_loss: 62424.8203 - val_mean_absolute_error: 249.7436
# Epoch 18/100
# 7/7 [==============================] - 0s 9ms/step - loss: 54522.0586 - mean_absolute_error: 231.3154 - val_loss: 57686.2305 - val_mean_absolute_error: 240.0693
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 49950.0898 - mean_absolute_error: 221.1797 - val_loss: 52498.5664 - val_mean_absolute_error: 229.0098
# Epoch 20/100
# 7/7 [==============================] - 0s 9ms/step - loss: 44984.6367 - mean_absolute_error: 209.6814 - val_loss: 47188.9805 - val_mean_absolute_error: 217.1083
# Epoch 21/100
# 7/7 [==============================] - 0s 8ms/step - loss: 40007.6602 - mean_absolute_error: 197.4758 - val_loss: 41745.3672 - val_mean_absolute_error: 204.1868
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 34806.4414 - mean_absolute_error: 183.7864 - val_loss: 36028.6836 - val_mean_absolute_error: 189.6726
# Epoch 23/100
# 7/7 [==============================] - 0s 12ms/step - loss: 29694.8555 - mean_absolute_error: 169.3546 - val_loss: 30699.9727 - val_mean_absolute_error: 175.0629
# Epoch 24/100
# 7/7 [==============================] - 0s 9ms/step - loss: 24890.8906 - mean_absolute_error: 154.4637 - val_loss: 25582.1094 - val_mean_absolute_error: 159.7784
# Epoch 25/100
# 7/7 [==============================] - 0s 9ms/step - loss: 20345.4902 - mean_absolute_error: 139.0214 - val_loss: 20819.5742 - val_mean_absolute_error: 144.1062
# Epoch 26/100
# 7/7 [==============================] - 0s 8ms/step - loss: 16207.3213 - mean_absolute_error: 123.2840 - val_loss: 16506.5547 - val_mean_absolute_error: 128.2715
# Epoch 27/100
# 7/7 [==============================] - 0s 8ms/step - loss: 12573.3828 - mean_absolute_error: 107.3299 - val_loss: 12665.4033 - val_mean_absolute_error: 112.3051
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9405.3789 - mean_absolute_error: 91.5465 - val_loss: 9426.6553 - val_mean_absolute_error: 96.8178
# Epoch 29/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6848.7349 - mean_absolute_error: 76.2729 - val_loss: 6778.9614 - val_mean_absolute_error: 82.0122
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4868.1470 - mean_absolute_error: 61.8576 - val_loss: 4717.9497 - val_mean_absolute_error: 68.3007
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3383.3010 - mean_absolute_error: 49.1531 - val_loss: 3215.9531 - val_mean_absolute_error: 56.2404
# Epoch 32/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2408.1709 - mean_absolute_error: 39.6133 - val_loss: 2132.7051 - val_mean_absolute_error: 45.6042
# Epoch 33/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1748.2538 - mean_absolute_error: 33.9260 - val_loss: 1400.7914 - val_mean_absolute_error: 36.7127
# Epoch 34/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1374.5778 - mean_absolute_error: 30.9648 - val_loss: 925.4402 - val_mean_absolute_error: 29.5377
# Epoch 35/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1170.3013 - mean_absolute_error: 28.9311 - val_loss: 634.9705 - val_mean_absolute_error: 24.1248
# Epoch 36/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1068.5116 - mean_absolute_error: 27.7436 - val_loss: 466.5720 - val_mean_absolute_error: 20.3373
# Epoch 37/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1026.4406 - mean_absolute_error: 27.1421 - val_loss: 366.8793 - val_mean_absolute_error: 17.7176
# Epoch 38/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1013.8157 - mean_absolute_error: 26.9048 - val_loss: 314.2640 - val_mean_absolute_error: 16.1647
# Epoch 39/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1008.7559 - mean_absolute_error: 26.8488 - val_loss: 284.7905 - val_mean_absolute_error: 15.2656
# Epoch 40/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.0455 - mean_absolute_error: 26.8599 - val_loss: 263.7495 - val_mean_absolute_error: 14.6147
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1009.9805 - mean_absolute_error: 26.8594 - val_loss: 261.8615 - val_mean_absolute_error: 14.5548
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.3979 - mean_absolute_error: 26.8673 - val_loss: 258.8812 - val_mean_absolute_error: 14.4596
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.2567 - mean_absolute_error: 26.8667 - val_loss: 256.7116 - val_mean_absolute_error: 14.3899
# Epoch 44/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.0682 - mean_absolute_error: 26.8837 - val_loss: 253.4419 - val_mean_absolute_error: 14.2841
# Epoch 45/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.8165 - mean_absolute_error: 26.8674 - val_loss: 265.0246 - val_mean_absolute_error: 14.6551
# Epoch 46/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1010.5378 - mean_absolute_error: 26.8673 - val_loss: 273.6761 - val_mean_absolute_error: 14.9257
# Epoch 47/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1011.0715 - mean_absolute_error: 26.8739 - val_loss: 266.6360 - val_mean_absolute_error: 14.7059
# Epoch 48/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1010.0346 - mean_absolute_error: 26.8592 - val_loss: 267.8401 - val_mean_absolute_error: 14.7437
# Epoch 49/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1009.8207 - mean_absolute_error: 26.8569 - val_loss: 270.8296 - val_mean_absolute_error: 14.8372
# Epoch 50/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1010.3483 - mean_absolute_error: 26.8652 - val_loss: 274.6127 - val_mean_absolute_error: 14.9546
# Epoch 51/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1011.9825 - mean_absolute_error: 26.8918 - val_loss: 258.1808 - val_mean_absolute_error: 14.4372
# Epoch 52/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1010.3669 - mean_absolute_error: 26.8717 - val_loss: 251.0276 - val_mean_absolute_error: 14.2054
# Epoch 53/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.7488 - mean_absolute_error: 26.8782 - val_loss: 252.8260 - val_mean_absolute_error: 14.2641
# Epoch 54/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.8145 - mean_absolute_error: 26.8775 - val_loss: 247.1472 - val_mean_absolute_error: 14.0780
# Epoch 55/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1010.5458 - mean_absolute_error: 26.8754 - val_loss: 251.7704 - val_mean_absolute_error: 14.2298
# Epoch 56/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1009.1622 - mean_absolute_error: 26.8430 - val_loss: 284.8008 - val_mean_absolute_error: 15.2728
# Epoch 57/100
# 7/7 [==============================] - 0s 12ms/step - loss: 984.2382 - mean_absolute_error: 26.5293 - val_loss: 328.0014 - val_mean_absolute_error: 16.6150
# Epoch 58/100
# 7/7 [==============================] - 0s 12ms/step - loss: 985.8829 - mean_absolute_error: 26.5543 - val_loss: 301.3445 - val_mean_absolute_error: 15.7908
# Epoch 59/100
# 7/7 [==============================] - 0s 12ms/step - loss: 978.3396 - mean_absolute_error: 26.4386 - val_loss: 311.1719 - val_mean_absolute_error: 16.1075
# Epoch 60/100
# 7/7 [==============================] - 0s 11ms/step - loss: 976.9533 - mean_absolute_error: 26.3956 - val_loss: 306.0051 - val_mean_absolute_error: 15.9517
# Epoch 61/100
# 7/7 [==============================] - 0s 11ms/step - loss: 967.4019 - mean_absolute_error: 26.2838 - val_loss: 366.0738 - val_mean_absolute_error: 17.7539
# Epoch 62/100
# 7/7 [==============================] - 0s 15ms/step - loss: 975.4142 - mean_absolute_error: 26.3596 - val_loss: 242.8283 - val_mean_absolute_error: 13.9690
# Epoch 63/100
# 7/7 [==============================] - 0s 12ms/step - loss: 963.5529 - mean_absolute_error: 26.2310 - val_loss: 289.5738 - val_mean_absolute_error: 15.4418
# Epoch 64/100
# 7/7 [==============================] - 0s 15ms/step - loss: 959.0598 - mean_absolute_error: 26.1779 - val_loss: 226.8815 - val_mean_absolute_error: 13.4299
# Epoch 65/100
# 7/7 [==============================] - 0s 17ms/step - loss: 952.2921 - mean_absolute_error: 26.1003 - val_loss: 273.6126 - val_mean_absolute_error: 14.9686
# Epoch 66/100
# 7/7 [==============================] - 0s 15ms/step - loss: 935.6808 - mean_absolute_error: 25.8579 - val_loss: 352.8915 - val_mean_absolute_error: 17.3994
# Epoch 67/100
# 7/7 [==============================] - 0s 12ms/step - loss: 956.1088 - mean_absolute_error: 26.0981 - val_loss: 245.3035 - val_mean_absolute_error: 14.0721
# Epoch 68/100
# 7/7 [==============================] - 0s 12ms/step - loss: 930.0052 - mean_absolute_error: 25.7764 - val_loss: 328.0406 - val_mean_absolute_error: 16.6735
# Epoch 69/100
# 7/7 [==============================] - 0s 12ms/step - loss: 922.3498 - mean_absolute_error: 25.6648 - val_loss: 265.1067 - val_mean_absolute_error: 14.7267
# Epoch 70/100
# 7/7 [==============================] - 0s 13ms/step - loss: 901.8621 - mean_absolute_error: 25.3690 - val_loss: 307.2589 - val_mean_absolute_error: 16.0771
# Epoch 71/100
# 7/7 [==============================] - 0s 15ms/step - loss: 872.7332 - mean_absolute_error: 24.9676 - val_loss: 330.2178 - val_mean_absolute_error: 16.8041
# Epoch 72/100
# 7/7 [==============================] - 0s 13ms/step - loss: 840.0024 - mean_absolute_error: 24.4330 - val_loss: 260.2883 - val_mean_absolute_error: 14.6202
# Epoch 73/100
# 7/7 [==============================] - 0s 13ms/step - loss: 820.8302 - mean_absolute_error: 24.2218 - val_loss: 285.4501 - val_mean_absolute_error: 15.4609
# Epoch 74/100
# 7/7 [==============================] - 0s 17ms/step - loss: 788.7706 - mean_absolute_error: 23.6646 - val_loss: 361.3287 - val_mean_absolute_error: 17.7923
# Epoch 75/100
# 7/7 [==============================] - 0s 13ms/step - loss: 753.9622 - mean_absolute_error: 23.1585 - val_loss: 302.3962 - val_mean_absolute_error: 16.0771
# Epoch 76/100
# 7/7 [==============================] - 0s 49ms/step - loss: 732.6533 - mean_absolute_error: 22.8454 - val_loss: 195.4880 - val_mean_absolute_error: 12.4692
# Epoch 77/100
# 7/7 [==============================] - 0s 9ms/step - loss: 693.8705 - mean_absolute_error: 21.9744 - val_loss: 140.4205 - val_mean_absolute_error: 10.1826
# Epoch 78/100
# 7/7 [==============================] - 0s 8ms/step - loss: 670.6649 - mean_absolute_error: 21.8130 - val_loss: 447.2916 - val_mean_absolute_error: 20.1731
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 640.8900 - mean_absolute_error: 21.2779 - val_loss: 142.6398 - val_mean_absolute_error: 10.3601
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 579.9216 - mean_absolute_error: 20.0940 - val_loss: 180.3934 - val_mean_absolute_error: 11.9960
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 534.3379 - mean_absolute_error: 19.3618 - val_loss: 261.9434 - val_mean_absolute_error: 14.9706
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 523.2786 - mean_absolute_error: 19.0946 - val_loss: 63.8744 - val_mean_absolute_error: 6.3717
# Epoch 83/100
# 7/7 [==============================] - 0s 9ms/step - loss: 530.2881 - mean_absolute_error: 19.5319 - val_loss: 85.6060 - val_mean_absolute_error: 7.5880
# Epoch 84/100
# 7/7 [==============================] - 0s 12ms/step - loss: 474.7545 - mean_absolute_error: 18.3977 - val_loss: 307.8226 - val_mean_absolute_error: 16.5216
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 415.6278 - mean_absolute_error: 16.8180 - val_loss: 165.9534 - val_mean_absolute_error: 11.5210
# Epoch 86/100
# 7/7 [==============================] - 0s 10ms/step - loss: 381.5723 - mean_absolute_error: 16.1449 - val_loss: 44.7721 - val_mean_absolute_error: 5.2729
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 370.9370 - mean_absolute_error: 15.8069 - val_loss: 181.6567 - val_mean_absolute_error: 12.1776
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 325.0970 - mean_absolute_error: 14.9577 - val_loss: 118.5532 - val_mean_absolute_error: 9.4432
# Epoch 89/100
# 7/7 [==============================] - 0s 10ms/step - loss: 287.2104 - mean_absolute_error: 14.0478 - val_loss: 148.5779 - val_mean_absolute_error: 10.8373
# Epoch 90/100
# 7/7 [==============================] - 0s 9ms/step - loss: 269.1465 - mean_absolute_error: 13.2197 - val_loss: 127.8137 - val_mean_absolute_error: 9.9121
# Epoch 91/100
# 7/7 [==============================] - 0s 9ms/step - loss: 234.4842 - mean_absolute_error: 12.1978 - val_loss: 58.0161 - val_mean_absolute_error: 6.1656
# Epoch 92/100
# 7/7 [==============================] - 0s 9ms/step - loss: 183.9257 - mean_absolute_error: 10.6515 - val_loss: 45.4482 - val_mean_absolute_error: 5.4790
# Epoch 93/100
# 7/7 [==============================] - 0s 9ms/step - loss: 156.9528 - mean_absolute_error: 9.8458 - val_loss: 52.0240 - val_mean_absolute_error: 5.9027
# Epoch 94/100
# 7/7 [==============================] - 0s 10ms/step - loss: 136.2493 - mean_absolute_error: 8.9179 - val_loss: 66.6268 - val_mean_absolute_error: 6.7869
# Epoch 95/100
# 7/7 [==============================] - 0s 12ms/step - loss: 111.5693 - mean_absolute_error: 8.1156 - val_loss: 41.3879 - val_mean_absolute_error: 5.3797
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 99.6664 - mean_absolute_error: 7.5931 - val_loss: 30.7056 - val_mean_absolute_error: 4.8908
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 81.6930 - mean_absolute_error: 6.6654 - val_loss: 30.2464 - val_mean_absolute_error: 4.8691
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 73.6695 - mean_absolute_error: 6.4094 - val_loss: 32.5342 - val_mean_absolute_error: 4.8350
# Epoch 99/100
# 7/7 [==============================] - 0s 9ms/step - loss: 66.7624 - mean_absolute_error: 6.1728 - val_loss: 30.5392 - val_mean_absolute_error: 4.8621
# Epoch 100/100
# 7/7 [==============================] - 0s 12ms/step - loss: 59.2135 - mean_absolute_error: 5.7733 - val_loss: 32.9665 - val_mean_absolute_error: 4.9663

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
